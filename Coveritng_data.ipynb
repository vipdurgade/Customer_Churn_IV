# %%
import pandas as pd

# %%
df = pd.read_csv('D:\IV_Mastertheis\Merged_kd_data.csv')

# List of columns where you want to remove '.'
columns_to_clean = ['gesbeitr', 'SCHAGESA', 'KOSTGESA', 'KOSTGEKA', 'kosten_verw', 'kosten_prov', 'SDBEITR5', 'KILOMETERSTAND']

# Remove '.' from each column (if any) and optionally convert to numeric
for col in columns_to_clean:
    # Convert to string, replace '.', and then convert to numeric (if needed)
    df[col] = df[col].astype(str).str.replace('.', '', regex=False)
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# <>:1: SyntaxWarning: invalid escape sequence '\I'
# C:\Users\VIP\AppData\Local\Temp\ipykernel_20696\2742015637.py:1: SyntaxWarning: invalid escape sequence '\I'
#   df = pd.read_csv('D:\IV_Mastertheis\Merged_kd_data.csv')
# C:\Users\VIP\AppData\Local\Temp\ipykernel_20696\2742015637.py:1: DtypeWarning: Columns (18,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('D:\IV_Mastertheis\Merged_kd_data.csv')
#      pvsnr          vsnr           vm status  aktiv  akt_kuka spartek  \
# 0  1012851  01012851-007  00 000 0101  Aktiv      1         1      VK
# 1  1012851  01012851-007  00 000 0101  Aktiv      1         1      KH
# 2  1013051  01013051-006  00 000 4305  Aktiv      1         1      VK
# 3  1013051  01013051-006  00 000 4305  Aktiv      1         1      KH
# 4  1020887  01020887-007  00 000 0119  Aktiv      1         1      KH
#
# ...

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#      pvsnr          vsnr           vm status  aktiv  akt_kuka spartek  \
# 0  1012851  01012851-007  00 000 0101  Aktiv      1         1      VK
# 1  1012851  01012851-007  00 000 0101  Aktiv      1         1      KH
# 2  1013051  01013051-006  00 000 4305  Aktiv      1         1      VK
# 3  1013051  01013051-006  00 000 4305  Aktiv      1         1      KH
# 4  1020887  01020887-007  00 000 0119  Aktiv      1         1      KH
#
#        beginn datum_s  vtr_dau    kund_beg vtrweg  STORNGRD gesbeitr  \
# 0  01.01.2025     NaN     89.0  11.05.1977      V       NaN    59777
# 1  01.01.2025     NaN     89.0  11.05.1977      V       NaN    21715
# 2  01.01.2025     NaN     89.0  17.07.1973      M       NaN    45825
# 3  01.01.2025     NaN     89.0  17.07.1973      M       NaN     2361
# 4  01.03.2025     NaN     30.0  10.02.1967      V       NaN      393
#
#    SDANZAHL SCHAGESA KOSTGESA KOSTGEKA kosten_verw kosten_prov  \
# ...
